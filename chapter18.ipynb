# %%
import pandas as pd

# %% [markdown]
# ### Question 1: Create a dataframe from the data and add it to itself.

# %%
df = pd.read_csv('attendance.csv')
df + df
# or
df.add(df)
# Out:
#                       Date                                      Away  \
# 0     2021-04-012021-04-01              Houston AstrosHouston Astros
# 1     2021-04-012021-04-01  Arizona DiamondbacksArizona Diamondbacks
# 2     2021-04-012021-04-01  San Francisco GiantsSan Francisco Giants
# 3     2021-04-012021-04-01              Atlanta BravesAtlanta Braves
# 4     2021-04-012021-04-01              Tampa Bay RaysTampa Bay Rays
# ...                    ...                                       ...
# 2365  2021-10-032021-10-03          Colorado RockiesColorado Rockies
# 2366  2021-10-032021-10-03        Oakland AthleticsOakland Athletics
# 2367  2021-10-032021-10-03            Minnesota TwinsMinnesota Twins
# 2368  2021-10-032021-10-03        Milwaukee BrewersMilwaukee Brewers
# 2369  2021-10-032021-10-03              Boston Red SoxBoston Red Sox
#
#                                             Home  Attendance Type
# 0             Oakland AthleticsOakland Athletics       20872   RR
# ...

# %% [markdown]
# ### Question 2: Create a dataframe from the data and multiply it by two.

# %%
df * 2
# or
df.mul(2)
# Out:
#                       Date                                      Away  \
# 0     2021-04-012021-04-01              Houston AstrosHouston Astros
# 1     2021-04-012021-04-01  Arizona DiamondbacksArizona Diamondbacks
# 2     2021-04-012021-04-01  San Francisco GiantsSan Francisco Giants
# 3     2021-04-012021-04-01              Atlanta BravesAtlanta Braves
# 4     2021-04-012021-04-01              Tampa Bay RaysTampa Bay Rays
# ...                    ...                                       ...
# 2365  2021-10-032021-10-03          Colorado RockiesColorado Rockies
# 2366  2021-10-032021-10-03        Oakland AthleticsOakland Athletics
# 2367  2021-10-032021-10-03            Minnesota TwinsMinnesota Twins
# 2368  2021-10-032021-10-03        Milwaukee BrewersMilwaukee Brewers
# 2369  2021-10-032021-10-03              Boston Red SoxBoston Red Sox
#
#                                             Home  Attendance Type
# 0             Oakland AthleticsOakland Athletics       20872   RR
# ...

# %% [markdown]
# ### Question 3: Are the results from the previous exercises equivalent?

# %%
df.add(df).equals(df.mul(2))
# Out:
# True
