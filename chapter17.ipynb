# %%
import pandas as pd

# %% [markdown]
# With a tabular dataset of your choice:
# ### Question 1: Create a data frame from the data

# %%
df = pd.read_csv('attendance.csv')

# %% [markdown]
# ### Question 2: View the first 20 rows of data

# %%
df.head(20)
# Out:
#           Date                  Away                   Home  Attendance Type
# 0   2021-04-01        Houston Astros      Oakland Athletics       10436    R
# 1   2021-04-01  Arizona Diamondbacks       San Diego Padres       10350    R
# 2   2021-04-01  San Francisco Giants       Seattle Mariners        8174    R
# 3   2021-04-01        Atlanta Braves  Philadelphia Phillies        8529    R
# 4   2021-04-01        Tampa Bay Rays          Miami Marlins        7062    R
# 5   2021-04-01     Toronto Blue Jays       New York Yankees       10850    R
# 6   2021-04-01       Minnesota Twins      Milwaukee Brewers       11740    R
# 7   2021-04-01     Chicago White Sox     Los Angeles Angels       13207    R
# 8   2021-04-01    Pittsburgh Pirates           Chicago Cubs       10343    R
# 9   2021-04-01   St. Louis Cardinals        Cincinnati Reds       12264    R
# 10  2021-04-01   Los Angeles Dodgers       Colorado Rockies       20570    R
# ...

# %% [markdown]
# ### Question 3: Sample 30 rows from your data

# %%
df.sample(n=30, random_state=42)
# Out:
#             Date                   Away                   Home  Attendance  \
# 1094  2021-06-25       Colorado Rockies      Milwaukee Brewers       31140
# 188   2021-04-16     Pittsburgh Pirates      Milwaukee Brewers       11967
# 1800  2021-08-21     Los Angeles Angels      Cleveland Indians       31406
# 707   2021-05-26   San Francisco Giants   Arizona Diamondbacks        8597
# 679   2021-05-24    St. Louis Cardinals      Chicago White Sox       14629
# 1937  2021-09-01           Chicago Cubs        Minnesota Twins       21784
# 210   2021-04-18      Baltimore Orioles          Texas Rangers       24267
# 1836  2021-08-24     Kansas City Royals         Houston Astros       22964
# 321   2021-04-27      Oakland Athletics         Tampa Bay Rays        2924
# 1829  2021-08-24         Tampa Bay Rays  Philadelphia Phillies       23402
# 528   2021-05-13      Toronto Blue Jays         Atlanta Braves       21653
# ...
